# %% [markdown]
# #Link do Drive com os arquivos dos datasets
#
# https://drive.google.com/drive/folders/1xyKHnd7IzcUiaaeS95k-LmQTfGPOYdZZ?usp=sharing

# %%
from scipy.io import arff
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arff_file = arff.loadarff('house_16H.arff')

df = pd.DataFrame(arff_file[0])

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

train_df.to_csv('train.csv', index=False)
test_df.to_csv('test.csv', index=False)

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
print("Distribuição da Variável Alvo - Treinamento")
print(train_df['binaryClass'].value_counts(normalize=True))
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='binaryClass')
plt.title("Distribuição da Variável Alvo")
plt.show()
# Out:
# Distribuição da Variável Alvo - Treinamento
# binaryClass
# P    0.704285
# N    0.295715
# Name: proportion, dtype: float64

# %%
print("Distribuição da Variável Alvo - Teste")
print(test_df['binaryClass'].value_counts(normalize=True))
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='binaryClass')
plt.title("Distribuição da Variável Alvo")
plt.show()
# Out:
# Distribuição da Variável Alvo - Teste
# binaryClass
# P    0.702875
# N    0.297125
# Name: proportion, dtype: float64
